# %% [markdown]
# # Installation

# %%
# !pip install tnreason==0.1
# Out:
# Collecting tnreason==0.1
#   Downloading tnreason-0.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from tnreason==0.1) (1.25.2)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tnreason==0.1) (2.0.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from tnreason==0.1) (3.2.1)
# Collecting rdflib (from tnreason==0.1)
#   Downloading rdflib-7.0.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.9/531.9 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from tnreason==0.1) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->tnreason==0.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->tnreason==0.1) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->tnreason==0.1) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tnreason==0.1) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tnreason==0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tnreason==0.1) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tnreason==0.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tnreason==0.1) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tnreason==0.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tnreason==0.1) (3.1.2)
# Collecting isodate<0.7.0,>=0.6.0 (from rdflib->tnreason==0.1)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from isodate<0.7.0,>=0.6.0->rdflib->tnreason==0.1) (1.16.0)
# Installing collected packages: isodate, rdflib, tnreason
# Successfully installed isodate-0.6.1 rdflib-7.0.0 tnreason-0.1

# %% [markdown]
# # Knowledge Base
#
# We demonstrate the ask and tell operation on a Knowledge Base containing the formulas $a_1$ and $a_1⇒a_2$.

# %%
from tnreason.model import tensor_kb

# %%
kb = tensor_kb.TensorKB([
    "a1",
    ["not",["a1", "and", ["not", "a2"]]]
])
# Out:
# Initialized a Knowledge Base with the formulas:
#   a1
#   ['not', ['a1', 'and', ['not', 'a2']]]

# %% [markdown]
# ## Ask Operation
#
# In the ask operation, we test whether a formula is entailed or contradicted by the Knowledge Base. If neither is the case, then the formula is contingent.

# %% [markdown]
# Example: $a_2$ is entailed by the Knowledge Base (by Modus Ponens).

# %%
kb.ask("a2")
# Out:
# a2 is entailed by the Knowledge Base.
# 'entailed'

# %% [markdown]
# Example: $\lnot a_1$ is contradicted by the Knowledge Base (since $a_1$ is a formula).

# %%
kb.ask(["not","a1"])
# Out:
# ['not', 'a1'] is contradicted by the Knowledge Base.
# 'contradicting'

# %% [markdown]
# Example: $a_3$ is not appearing in the formulas of the Knowledge Base and thus contingent.

# %%
kb.ask("a3")
# Out:
# a3 is neither entailed nor contradicted by the Knowledge Base.
# 'contingent'

# %% [markdown]
# ## Tell Operation
#
# In the tell operation, a new formula is added to the knowledge base. To prevent redundancies of the representation and inconsistencies, we first perform a test of entailment and contradiction. Only when both are negative, the formula is added.

# %% [markdown]
# Example: $a_1$ is a formula contained in the Knowledge Base, therefor entailed and not added due to redundancy.

# %%
kb.tell("a1")
# Out:
# a1 is entailed by the Knowledge Base.
# a1 is redundant to the Knowledge Base and has not been added.
# 'not added'

# %% [markdown]
# Example: $\lnot a_1$ is contradicted by the Knowledge Base and adding it would thus make the Knowledge Base inconsistent.

# %%
kb.tell(["not","a1"])
# Out:
# ['not', 'a1'] is contradicted by the Knowledge Base.
# ['not', 'a1'] would make the Knowledge Base inconsistent and has not been added.
# 'not added'

# %% [markdown]
# Example: $a_4$ can be added by the tell operation, since not appearing in any formula of the Knowledge Base.

# %%
kb.tell("a4")
# Out:
# a4 is neither entailed nor contradicted by the Knowledge Base.
# a4 has been added to the Knowledge Base.
# 'added'

# %%
kb.formulaList
# Out:
# ['a1', ['not', ['a1', 'and', ['not', 'a2']]], 'a4']
